# %%
import os
import pandas as pd
import shutil

# %%
df_info = pd.read_csv('../../raw_data/interviewee_infomation/roundAll_info_final.csv')
df_info.head(2)
# Out:
#   访谈员编号            转录稿文件名 个人代号（昵称）  第几轮访谈                           信息汇总表文件名  \
# 0  Lily     WLL_文已校对（桂笑言）        文      1             20211024_文_访谈信息汇总表-桂笑言
# 1   NaN  WLL_黄师傅-已校对（彭楚玥）      黄师傅      1  20211014_黄师傅-访谈信息汇总表-彭楚玥-20211023
#
#   访谈编号 性别  出生年份 是否出生在深圳  抵深年份   学历     身份（职业/行业） 主要生活区域  关内关外
# 0  NaN  男  2001       是  2001  NaN            学生    NaN   NaN
# 1  NaN  男    未知       否   NaN  NaN  包子店老板（网约车司机）    NaN   NaN

# %%
script_withmorePeople_noAge = df_info["转录稿文件名"].value_counts()[df_info["转录稿文件名"].value_counts()>1].index.tolist()

script_withmorePeople_noAge.extend(['3_SZTUWWX_邓先生王女士','3_SZTUWWX_谭女士霍先生','10_SZTU-lx_凹凸曼&李先生',"WLL_黄师傅-已校对（彭楚玥）","MJY_02-尹先生"])
script_withmorePeople_noAge
# Out:
# ['LZY_张氏父女',
#  'XRH_02_ZhengFj',
#  '3_SZTUWWX_邓先生王女士',
#  '3_SZTUWWX_谭女士霍先生',
#  '10_SZTU-lx_凹凸曼&李先生',
#  'WLL_黄师傅-已校对（彭楚玥）',
#  'MJY_02-尹先生']

# %%
df_info["year"] = df_info["出生年份"]
s_index = df_info[df_info["year"].str.endswith("s")].index
df_info.loc[s_index,"year"] = df_info[df_info["year"].str.endswith("s")]["year"].str[:-1]

# %%
df_info.loc[~df_info["转录稿文件名"].isin(script_withmorePeople_noAge),["转录稿文件名","出生年份"]].sort_values("出生年份")
# Out:
#                转录稿文件名  出生年份
# 88     10_SZTU-lx_何爷爷  1943
# 23      sustech_LHY_2  1949
# 58     13_SZTULJK_HYZ  1950
# 25  SZTU_CXY_02_录音转录稿  1951
# 71     11_SZUH_YUNWEI  1954
# ..                ...   ...
# 19   yuan-peng_方艺钧-校稿  2001
# 9            WZY_04-江  2001
# 60      3_SZTUWWX_陈女士  2002
# 39    8_hkust_wdq_yyq  2003
# 61      3_SZTUWWX_李先生  2003
#
# [82 rows x 2 columns]

# %%
my_dir = [ 'round1_csv',
 'round2_csv',
 'round3_csv',
 'round4_csv',
 ]

## mydir用完后已经被删除了

for dir in my_dir:
    for file in os.listdir(f"../地名实体识别汇总（round1-4）/{dir}"):
        file_name, file_extension = os.path.splitext(file)

        source_file_path = os.path.join(f"../地名实体识别汇总（round1-4）/{dir}", file)

        if file_name in script_withmorePeople_noAge:
            destination_file_path = os.path.join("others",file)
            shutil.copy(source_file_path, destination_file_path)
            continue

        # print(file_name)
        year = int(df_info[df_info["转录稿文件名"]==file_name]["year"].values[0])
        # print(year)

        if year < 1950:
            destination_file_path = os.path.join("less1950",file)
        if year >= 1950 and year < 1960:
            destination_file_path = os.path.join("1950-1960",file)
        if year >= 1960 and year < 1970:
            destination_file_path = os.path.join("1960-1970",file)
        if year >= 1970 and year < 1980:
            destination_file_path = os.path.join("1970-1980",file)
        if year >= 1980 and year < 1990:
            destination_file_path = os.path.join("1980-1990",file)
        if year >= 1990 and year < 2000:
            destination_file_path = os.path.join("1990-2000",file)
        if year >= 2000:
            destination_file_path = os.path.join("2000+",file)


        shutil.copy(source_file_path, destination_file_path)
