# %%
import pandas as pd
df = pd.read_csv("../YouTube-videos-new.csv")
df
# Out:
#     视频编号                                         视频网址  \
# 0      1  https://www.youtube.com/watch?v=9bqFjcDeVIg
# 1      2  https://www.youtube.com/watch?v=rz7mIarbxNY
# 2      3  https://www.youtube.com/watch?v=-XcGW_L1N0k
# 3      4  https://www.youtube.com/watch?v=IZoFnsYw7VM
# 4      5  https://www.youtube.com/watch?v=Nr1W7h1j99w
# 5      6  https://www.youtube.com/watch?v=K3X46veg64I
# 6      7  https://www.youtube.com/watch?v=b5FtjD2I8es
# 7      8  https://www.youtube.com/watch?v=xuj6DwimRaw
# 8      9  https://www.youtube.com/watch?v=kYpeA_kVcI8
# 9     10  https://www.youtube.com/watch?v=XM-s2l3tlos
# 10    11  https://www.youtube.com/watch?v=_UGOUnwJxyo
# 11    12  https://www.youtube.com/watch?v=Ft8yt0S3MxA
# 12    13  https://www.youtube.com/watch?v=oxqQI9VkWN0
# 13    14  https://www.youtube.com/watch?v=r9TAGdsy8Xk
# 14    15  https://www.youtube.com/watch?v=7ES4SgUTyl4
# 15    16  https://www.youtube.com/watch?v=3tzFErLzoJ4
# ...

# %%
# import os 
# os.mkdir("comment_100")

# tmp = df["video_id"].to_list()
# for i in tmp:
#     file_path = f"comment_100/{i}.json"
#     with open(file_path, "w") as file:
#         # file.write(file_content)
#         file.write(i)
